# %%
from importlib import reload
from utils.scraper import phone_number_scaper
reload(phone_number_scaper)
url = "https://turbo.az/autos"
first_page = 1
end_page = 1

# %%
t = phone_number_scaper.get_numbers(
                url,
                page_query_param='page',
                not_found_class='not_found',
                item_link_class="products-i__link",
                store_item_link_class="shop-contact--phones-number",
                item_class="phone",
                first_page=int(first_page),
                end_page=int(end_page)

            )

# %%
import pprint
pprint.pprint(t, indent=4)
